# %% [markdown]
# *   Multimídia - Matrizes e Vetores (Exercício 6)
#
# *   Felipe Daniel Dias dos Santos - 11711ECP004
#
# *   Graduação em Engenharia de Computação - Faculdade de Engenharia Elétrica - Universidade Federal de Uberlândia

# %%
#Imagem "teste1" em cinza e seu tamanho
import numpy as np
import matplotlib.pyplot as plt
import imageio as im
from google.colab import drive
from matplotlib import pyplot as plt
import cv2

drive.mount('/content/gdrive/')

root_path = '/content/gdrive/My Drive/Colab Notebooks/'

image_1 = im.imread(root_path + 'dados/teste1.png')
plt.imshow(image_1, cmap = 'gray')
image_1.size
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# 200

# %%
#Imagem "teste1" em outra escala de cores
imgage_2 = cv2.imread(root_path + 'dados/teste1.png', 0)
plt.imshow(imgage_2)
plt.show()

# %%
#Informações sobre a imagem "teste1"

#a) Número de linhas e colunas da imagem "teste1"
print(image_1.shape)

#b) Atribuição dos valores das linhas e colunas às variáveis M e N:
[M, N] = image_1.shape
print(M, N)
# Out:
# (10, 20)
# 10 20

# %%
#Imagem "rose_gray" em cinza e seu tamanho
image_3 = im.imread(root_path + 'dados/rose_gray.tif')
plt.imshow(image_3, cmap = 'gray')
image_3.size
# Out:
# 69432

# %%
#Imagem "rose_gray" em outra escala de cores
imgage_4 = cv2.imread(root_path + 'dados/rose_gray.tif', 0)
plt.imshow(imgage_4)
plt.show()

# %%
#Informações sobre a imagem "rose_gray"

#a) Número de linhas e colunas da imagem "rose_gray"
print(image_3.shape)

#b) Atribuição dos valores das linhas e colunas às variáveis J e K:
[J, K] = image_3.shape
print(J, K)
# Out:
# (263, 264)
# 263 264
