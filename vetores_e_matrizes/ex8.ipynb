# %% [markdown]
# *   Multimídia - Matrizes e Vetores (Exercício 8)
#
# *   Felipe Daniel Dias dos Santos - 11711ECP004
#
# *   Graduação em Engenharia de Computação - Faculdade de Engenharia Elétrica - Universidade Federal de Uberlândia

# %%
import wave

root_path = '/content/gdrive/My Drive/Colab Notebooks/'

arquivoWav = wave.open(root_path + 'dados/vocal.wav', 'r')
print('Número canais:', arquivoWav.getnchannels())
print('Compactação: ', arquivoWav.getcompname())
print('Taxa de amostragem: ', arquivoWav.getframerate())
# Out:
# Número canais: 1
# Compactação:  not compressed
# Taxa de amostragem:  44100

# %% [markdown]
# Observa-se que, de acordo com as funções "getnchannels" e "getframerate", esse áudio possui 1 canal e uma taxa de amostragem de 44100 Hz.
